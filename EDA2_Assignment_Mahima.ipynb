# %% [markdown]
# # EDA == Exploratory Data Analysis
#
# #### Exploratory Data analysis (EDA) is a crucial initial step in data analysis, aimed at summerzing kry characterastics ,visulaizing pattern ,and gaining a deeper understanding of data set . python offers powerful libraries such as pandas ,Numpy Matplotlib and Seaborn to facillate effictive EDA.

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# load and read the dataset
df = pd.read_csv("thyroid_cancer_risk_data.csv")
df
# Out:
#         Patient_ID  Age  Gender  Country       Ethnicity Family_History  \
# 0                1   66    Male   Russia       Caucasian             No
# 1                2   29    Male  Germany        Hispanic             No
# 2                3   86    Male  Nigeria       Caucasian             No
# 3                4   75  Female    India           Asian             No
# 4                5   35  Female  Germany         African            Yes
# ...            ...  ...     ...      ...             ...            ...
# 212686      212687   58  Female    India           Asian             No
# 212687      212688   89    Male    Japan  Middle Eastern             No
# 212688      212689   72  Female  Nigeria        Hispanic             No
# 212689      212690   85  Female   Brazil  Middle Eastern             No
# 212690      212691   46  Female    Japan  Middle Eastern             No
#
#        Radiation_Exposure Iodine_Deficiency Smoking Obesity Diabetes  \
# ...

# %% [markdown]
# ## Insight : Read csv file and show data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212691 entries, 0 to 212690
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Patient_ID           212691 non-null  int64
#  1   Age                  212691 non-null  int64
#  2   Gender               212691 non-null  object
#  3   Country              212691 non-null  object
#  4   Ethnicity            212691 non-null  object
#  5   Family_History       212691 non-null  object
#  6   Radiation_Exposure   212691 non-null  object
#  7   Iodine_Deficiency    212691 non-null  object
#  8   Smoking              212691 non-null  object
#  9   Obesity              212691 non-null  object
#  10  Diabetes             212691 non-null  object
#  11  TSH_Level            212691 non-null  float64
#  12  T3_Level             212691 non-null  float64
#  13  T4_Level             212691 non-null  float64
# ...

# %% [markdown]
# ## Insight :  Show the Index Information , Column Details , Non-Null Count , Dtype summary and Memory Usage.

# %%
df.columns
# Out:
# Index(['Patient_ID', 'Age', 'Gender', 'Country', 'Ethnicity', 'Family_History',
#        'Radiation_Exposure', 'Iodine_Deficiency', 'Smoking', 'Obesity',
#        'Diabetes', 'TSH_Level', 'T3_Level', 'T4_Level', 'Nodule_Size',
#        'Thyroid_Cancer_Risk', 'Diagnosis'],
#       dtype='object')

# %% [markdown]
# ## Insight : Retrieve all Column Names in dataset.

# %%
#statistical description
df.describe()
# Out:
#          Patient_ID            Age      TSH_Level       T3_Level  \
# count  212691.00000  212691.000000  212691.000000  212691.000000
# mean   106346.00000      51.918497       5.045102       2.001727
# std     61398.74739      21.632815       2.860264       0.866248
# min         1.00000      15.000000       0.100000       0.500000
# 25%     53173.50000      33.000000       2.570000       1.250000
# 50%    106346.00000      52.000000       5.040000       2.000000
# 75%    159518.50000      71.000000       7.520000       2.750000
# max    212691.00000      89.000000      10.000000       3.500000
#
#             T4_Level    Nodule_Size
# count  212691.000000  212691.000000
# mean        8.246204       2.503403
# std         2.164188       1.444631
# min         4.500000       0.000000
# 25%         6.370000       1.250000
# 50%         8.240000       2.510000
# 75%        10.120000       3.760000
# max        12.000000       5.000000

# %% [markdown]
# ## Insight : Summarizes numerical columns with the statistics.

# %%
df.isna().sum()
# Out:
# Patient_ID             0
# Age                    0
# Gender                 0
# Country                0
# Ethnicity              0
# Family_History         0
# Radiation_Exposure     0
# Iodine_Deficiency      0
# Smoking                0
# Obesity                0
# Diabetes               0
# TSH_Level              0
# T3_Level               0
# T4_Level               0
# Nodule_Size            0
# Thyroid_Cancer_Risk    0
# Diagnosis              0
# dtype: int64

# %% [markdown]
# ## Insight : Detection of Missing Values in all columns.

# %%
print(" 4.  Duplicate records : " ,df.duplicated().sum())
# Out:
#  4.  Duplicate records :  0

# %% [markdown]
# ## Insight : show duplicate records.

# %% [markdown]
# # Age :

# %%
df['Age'].mean()
# Out:
# 51.918496786417855

# %% [markdown]
# ## Insight : show the mean of Age.

# %%
df['Age'].mode()
# Out:
# 0    72
# Name: Age, dtype: int64

# %% [markdown]
# ## Insight : show the Mode of Age (The most frequently occurring age.)

# %% [markdown]
# ## Histogram

# %%
df['Age'].plot(kind = "hist", edgecolor = "black")
plt.title("Age Distribution of Patient")
plt.xlabel("Age")
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Insight : Displays the frequency distribution of ages.( below 20 , 30 to 35 and 55 to 60 age age count is higher )

# %% [markdown]
# # Gender :

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    127527
# Male       85164
# Name: count, dtype: int64

# %% [markdown]
# ## Insight : show the count of Female and male.

# %%
df.groupby('Gender')['Age'].mean()
# Out:
# Gender
# Female    51.921170
# Male      51.914494
# Name: Age, dtype: float64

# %% [markdown]
# ## Insight : This computes the average age for each gender category

# %% [markdown]
# ## Bar plot :

# %%
df['Gender'].value_counts().plot(kind='bar', color=['pink', 'lightblue'])
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Insight : count of gender (the female count is higher as compaired to male)

# %% [markdown]
# # Country :

# %%
df.Country
# Out:
# 0          Russia
# 1         Germany
# 2         Nigeria
# 3           India
# 4         Germany
#            ...
# 212686      India
# 212687      Japan
# 212688    Nigeria
# 212689     Brazil
# 212690      Japan
# Name: Country, Length: 212691, dtype: object

# %% [markdown]
# ## Insight : show all country column , length , its indexing and show its datatype.

# %%
unique_countries = df['Country'].unique()
print(unique_countries)
# Out:
# ['Russia' 'Germany' 'Nigeria' 'India' 'UK' 'South Korea' 'Brazil' 'China'
#  'Japan' 'USA']

# %% [markdown]
# ## Insight : To see all unique countries present in the dataset.

# %%
country_counts = df['Country'].value_counts()
print(country_counts)
# Out:
# Country
# India          42496
# China          31978
# Nigeria        31918
# Brazil         21413
# Russia         21297
# Japan          16867
# South Korea    14965
# UK             10642
# USA            10558
# Germany        10557
# Name: count, dtype: int64

# %% [markdown]
# ## Insight : To determine how many times each country appears.

# %%
india_data = df[df['Country'] == 'Germany']
print(india_data)
# Out:
#         Patient_ID  Age  Gender  Country       Ethnicity Family_History  \
# 1                2   29    Male  Germany        Hispanic             No
# 4                5   35  Female  Germany         African            Yes
# 9               10   36    Male  Germany           Asian             No
# 34              35   65  Female  Germany         African            Yes
# 59              60   68  Female  Germany       Caucasian             No
# ...            ...  ...     ...      ...             ...            ...
# 212614      212615   75  Female  Germany         African             No
# 212619      212620   79  Female  Germany       Caucasian            Yes
# 212622      212623   55  Female  Germany  Middle Eastern             No
# 212641      212642   50  Female  Germany       Caucasian            Yes
# 212681      212682   68  Female  Germany       Caucasian             No
#
#        Radiation_Exposure Iodine_Deficiency Smoking Obesity Diabetes  \
# ...

# %% [markdown]
# ## Insight : To focus on data from a particular country, such as Germany and shows how many columns and rows included.

# %% [markdown]
# ## Bar Plot

# %%
df['Country'].value_counts().plot(kind='bar', figsize=(12, 6))
plt.title('Number of Records per Country')
plt.xlabel('Country')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Insight : This bar chart provides a clear visual representation of the data distribution across countries. (the highest count country is India and lowest count country is Germany)

# %% [markdown]
# # Ethnicity :

# %%
df['Ethnicity'].value_counts()
# Out:
# Ethnicity
# Caucasian         63669
# Asian             53261
# African           42414
# Hispanic          32012
# Middle Eastern    21335
# Name: count, dtype: int64

# %% [markdown]
# ## Insight : Determine the count of each unique ethnicity and show its data type.

# %%
df.groupby('Ethnicity')['Age'].mean()
# Out:
# Ethnicity
# African           51.996959
# Asian             51.867840
# Caucasian         51.962399
# Hispanic          51.892197
# Middle Eastern    51.797422
# Name: Age, dtype: float64

# %% [markdown]
# ## Insight : Calculate statistics for numerical variables grouped by ethnicity and show its datatype . For example, average age

# %%
df['Ethnicity'].unique()
# Out:
# array(['Caucasian', 'Hispanic', 'Asian', 'African', 'Middle Eastern'],
#       dtype=object)

# %% [markdown]
# ## Pie plot :

# %%
df['Ethnicity'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Ethnicity by Percentage")
plt.show()

# %% [markdown]
# ## Insight : show the percentage wise count of Ethnicity. (In this graph show the highest percentage is caucasian Ethnicity)

# %% [markdown]
# ## Line Plot

# %%
df.groupby("Ethnicity")["TSH_Level"].sum().plot(kind = "line")
plt.title("Line plot for TSH_Level Groupedby Ethnicity")
plt.show()

# %% [markdown]
# ## Insight : show the count of Ethnicity.

# %% [markdown]
# # Family_History :

# %%
df['Family_History'].value_counts()
# Out:
# Family_History
# No     148866
# Yes     63825
# Name: count, dtype: int64

# %% [markdown]
# ## Insight : This will display the count of each unique value and show its datatype.

# %%
print(df['Family_History'].value_counts(normalize=True, dropna=False) * 100)
# Out:
# Family_History
# No     69.991678
# Yes    30.008322
# Name: proportion, dtype: float64

# %% [markdown]
# ## Insight : show the percentage wise family history and its data type .

# %% [markdown]
# ## Bar plot

# %%
sns.countplot(x='Family_History', data=df)
plt.title('Distribution of Family History Responses')
plt.xlabel('Family History')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Insight : display the family history count of unique value.(no count is higher as compaired to yes)

# %% [markdown]
# # Smoking , Obesity and Diabetes :

# %%
df['Smoking'].value_counts()
# Out:
# Smoking
# No     170260
# Yes     42431
# Name: count, dtype: int64

# %%
df['Obesity'].value_counts()
# Out:
# Obesity
# No     148805
# Yes     63886
# Name: count, dtype: int64

# %%
df['Diabetes'].value_counts()
# Out:
# Diabetes
# No     170098
# Yes     42593
# Name: count, dtype: int64

# %% [markdown]
# ## Insight : This will show the count of each unique value.(Smoking , Obesity and Diabetes)

# %%
print("Smoking:\n", df['Smoking'].value_counts(normalize=True, dropna=False) * 100)
print("\nObesity:\n", df['Obesity'].value_counts(normalize=True, dropna=False) * 100)
print("\nDiabetes:\n", df['Diabetes'].value_counts(normalize=True, dropna=False) * 100)
# Out:
# Smoking:
#  Smoking
# No     80.050402
# Yes    19.949598
# Name: proportion, dtype: float64
#
# Obesity:
#  Obesity
# No     69.962998
# Yes    30.037002
# Name: proportion, dtype: float64
#
# Diabetes:
#  Diabetes
# No     79.974235
# Yes    20.025765
# Name: proportion, dtype: float64

# %% [markdown]
# ## Insight : This will show the percentage of each unique value.(Smoking , Obesity and Diabetes)

# %% [markdown]
# ## Bar plot :

# %%
risk_factors = ['Smoking', 'Obesity', 'Diabetes']

# Count the "Yes"/"No" values for each
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
for i, factor in enumerate(risk_factors):
    df[factor].value_counts().plot(kind='bar', ax=axs[i], color=['red', 'blue'])
    axs[i].set_title(f'{factor} Distribution')
    axs[i].set_ylabel('Count')
    axs[i].set_xlabel(factor)
    axs[i].set_xticklabels(axs[i].get_xticklabels(), rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Insight : These bar charts will visually depict the frequency of each category (its show the count of No is higher as compaired to Yes in smoking , obesity and diabetes)

# %% [markdown]
# ## TSH_Level	, T3_Level , T4_Level and Nodule_Size :

# %% [markdown]
# ## Box Plot

# %%
sns.boxplot(data = df [['TSH_Level', 'T3_Level', 'T4_Level', 'Nodule_Size']])
plt.title('Age Distribution by Thyroid Cancer Risk')
plt.xlabel('Risk Category')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# ## Insight : Display the risk category of t4 level is higher as compaired to the other level.

# %% [markdown]
# # Bar plot

# %%
#Group by Diagnosis and plot average hormone levels
hormone_means = df.groupby('Diagnosis')[['TSH_Level', 'T3_Level', 'T4_Level']].mean()

hormone_means.plot(kind='bar', figsize=(10, 6))
plt.title('Average Hormone Levels by Diagnosis')
plt.ylabel('Hormone Level')
plt.xlabel('Diagnosis')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Insight :  show the t4 level is higher as compaired to t3 level and TSH level base on diagnosis.

# %% [markdown]
# # Thyroid cancer risk :

# %%
df.Thyroid_Cancer_Risk
# Out:
# 0            Low
# 1            Low
# 2            Low
# 3         Medium
# 4           High
#            ...
# 212686       Low
# 212687    Medium
# 212688    Medium
# 212689    Medium
# 212690       Low
# Name: Thyroid_Cancer_Risk, Length: 212691, dtype: object

# %% [markdown]
# ## Insight : show all Thyroid_Cancer_Risk column , length , its indexing  and show its datatype.

# %%
unique_Thyroid_Cancer_Risk = df['Thyroid_Cancer_Risk'].unique()
print(unique_Thyroid_Cancer_Risk )
# Out:
# ['Low' 'Medium' 'High']

# %% [markdown]
# ## Insight : To see all unique value in Thyroid_Cancer_Risk column present in the dataset.

# %% [markdown]
# ## Pie Plot

# %%
thyroid_cancer_risk_counts = df['Thyroid_Cancer_Risk'].value_counts()

plt.pie(
    thyroid_cancer_risk_counts,
    labels = thyroid_cancer_risk_counts.index,
    autopct ='%1.1f%%',       
    startangle = 140,          
    colors = ['green', 'orange','blue'],  
    wedgeprops = {'edgecolor': 'black'} 
)
plt.title('Thyroid Cancer Risk Distribution')
plt.axis('equal')  # Equal aspect ratio ensures pie is a circle
plt.show()

# %% [markdown]
# ## Insight : to show the count percentage of Thyroid_Cancer_Risk(The low count is higher as compaired to other)

# %% [markdown]
# # Box plot

# %%
plt.figure(figsize=(7, 5))
sns.boxplot(x='Family_History', y='Thyroid_Cancer_Risk', data=df)
plt.title('Family History vs Cancer Risk')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Insight : thyroid risk cancer base on family history is higher .

# %% [markdown]
# # Diagnosis :

# %%
df.Diagnosis
# Out:
# 0            Benign
# 1            Benign
# 2            Benign
# 3            Benign
# 4            Benign
#             ...
# 212686       Benign
# 212687       Benign
# 212688       Benign
# 212689       Benign
# 212690    Malignant
# Name: Diagnosis, Length: 212691, dtype: object

# %% [markdown]
# ## Insight : display all Diagnosis column , its length and show data type.

# %%
df.groupby('Thyroid_Cancer_Risk')['Age'].mean()
# Out:
# Thyroid_Cancer_Risk
# High      52.040999
# Low       51.853923
# Medium    51.961188
# Name: Age, dtype: float64

# %% [markdown]
# ## Pie plot

# %%
diagnosis_counts = df['Diagnosis'].value_counts()

plt.pie(diagnosis_counts, labels = diagnosis_counts.index, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)
plt.title('Diagnosis Distribution')
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Insight: Shows the proportion of different thyroid conditions in the dataset.(the Diagnosis count of Bening is higher as compaired to count of malignant)
